# %%
import pandas as pd
df = pd.read_csv("https://github.com/codeforamerica/ohana-api/raw/master/data/sample-csv/addresses.csv")
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
# FILE OPERATIONS USING PANDAS
df1 = pd.read_csv("https://github.com/codeforamerica/ohana-api/raw/master/data/sample-csv/addresses.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.read_csv("https://github.com/codeforamerica/ohana-api/raw/master/data/sample-csv/addresses.csv", sep=',',header=None, skiprows=[3,4,5],names=[0,1,2,3,4,5,6,'Abhinavkxmkon'])
df1
# Out:
#      0            1                           2          3  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    6            6           800 Middle Avenue        NaN
# 4    7            7              500 Arbor Road        NaN
# 5    8            8           800 Middle Avenue        NaN
# 6    9            9       2510 Middlefield Road        NaN
# 7   10           10       1044 Middlefield Road        NaN
# 8   11           11         2140 Euclid Avenue.        NaN
# 9   12           12       1044 Middlefield Road  2nd Floor
# 10  13           13         399 Marine Parkway.        NaN
# 11  14           14          660 Veterans Blvd.        NaN
# 12  15           15        1500 Valencia Street        NaN
# 13  16           16         1161 South Bernardo        NaN
# 14  17           17     409 South Spruce Avenue        NaN
# ...

# %%
df.to_csv("abc.csv")
ad = pd.read_csv("abc.csv")
ad
# Out:
#     Unnamed: 0  id  location_id                   address_1  address_2  \
# 0            0   1            1       2600 Middlefield Road        NaN
# 1            1   2            2            24 Second Avenue        NaN
# 2            2   3            3            24 Second Avenue        NaN
# 3            3   4            4            24 Second Avenue        NaN
# 4            4   5            5            24 Second Avenue        NaN
# 5            5   6            6           800 Middle Avenue        NaN
# 6            6   7            7              500 Arbor Road        NaN
# 7            7   8            8           800 Middle Avenue        NaN
# 8            8   9            9       2510 Middlefield Road        NaN
# 9            9  10           10       1044 Middlefield Road        NaN
# 10          10  11           11         2140 Euclid Avenue.        NaN
# 11          11  12           12       1044 Middlefield Road  2nd Floor
# ...

# %%
ad.describe()
# Out:
#        Unnamed: 0         id  location_id
# count   21.000000  21.000000    21.000000
# mean    10.000000  11.000000    11.095238
# std      6.204837   6.204837     6.363213
# min      0.000000   1.000000     1.000000
# 25%      5.000000   6.000000     6.000000
# 50%     10.000000  11.000000    11.000000
# 75%     15.000000  16.000000    16.000000
# max     20.000000  21.000000    22.000000

# %%
ad.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
ad[ad.dtypes[ad.dtypes=="object"].index]
# Out:
#                      address_1  address_2                 city state_province  \
# 0        2600 Middlefield Road        NaN         Redwood City             CA
# 1             24 Second Avenue        NaN            San Mateo             CA
# 2             24 Second Avenue        NaN            San Mateo             CA
# 3             24 Second Avenue        NaN            San Mateo             CA
# 4             24 Second Avenue        NaN            San Mateo             CA
# 5            800 Middle Avenue        NaN           Menlo Park             CA
# 6               500 Arbor Road        NaN           Menlo Park             CA
# 7            800 Middle Avenue        NaN           Menlo Park             CA
# 8        2510 Middlefield Road        NaN         Redwood City             CA
# 9        1044 Middlefield Road        NaN         Redwood City             CA
# 10         2140 Euclid Avenue.        NaN         Redwood City             CA
# ...

# %%
ad.dtypes[ad.dtypes=="object"]
# Out:
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
[ad.dtypes=="object"]
# Out:
# [Unnamed: 0        False
#  id                False
#  location_id       False
#  address_1          True
#  address_2          True
#  city               True
#  state_province     True
#  postal_code        True
#  country            True
#  dtype: bool]

# %%
ad[ad.dtypes[ad.dtypes=="object"].index].describe()
# Out:
#                address_1  address_2          city state_province postal_code  \
# count                 21          2            21             21          21
# unique                16          2             7              1          12
# top     24 Second Avenue  2nd Floor  Redwood City             CA       94063
# freq                   4          1             8             21           6
#
#        country
# count       21
# unique       1
# top         US
# freq        21

# %%
ad.columns
# Out:
# Index(['Unnamed: 0', 'id', 'location_id', 'address_1', 'address_2', 'city',
#        'state_province', 'postal_code', 'country'],
#       dtype='object')

# %%
ad.head()
# Out:
#    Unnamed: 0  id  location_id              address_1 address_2          city  \
# 0           0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1           1   2            2       24 Second Avenue       NaN     San Mateo
# 2           2   3            3       24 Second Avenue       NaN     San Mateo
# 3           3   4            4       24 Second Avenue       NaN     San Mateo
# 4           4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
ad.tail()
# Out:
#     Unnamed: 0  id  location_id                   address_1  address_2  \
# 16          16  17           17     409 South Spruce Avenue        NaN
# 17          17  18           18            114 Fifth Avenue        NaN
# 18          18  19           19         19 West 39th Avenue        NaN
# 19          19  20           21          123 El Camino Real        NaN
# 20          20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
pd.Categorical(ad)
# Out:
# ['Unnamed: 0', 'id', 'location_id', 'address_1', 'address_2', 'city', 'state_province', 'postal_code', 'country']
# Categories (9, object): ['Unnamed: 0', 'address_1', 'address_2', 'city', ..., 'id', 'location_id',
#                          'postal_code', 'state_province']

# %%
pd.Categorical(ad["state_province"])
# Out:
# ['CA', 'CA', 'CA', 'CA', 'CA', ..., 'CA', 'CA', 'CA', 'CA', 'CA']
# Length: 21
# Categories (1, object): ['CA']

# %%
type(ad.dtypes)
# Out:
# pandas.core.series.Series

# %%
# SERIES IN PANDAS
av= df.dtypes
av
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
av["address_1"]
# Out:
# dtype('O')

# %%
av['location_id']
# Out:
# dtype('int64')

# %%
av[0]
# Out:
# <ipython-input-49-c474f6256c68>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   av[0]
# dtype('int64')

# %%
n= [0.45,45,33,4,6,7,89,9,2235,4,55,"abhinav",'kjernoj']

# %%
n[0]
# Out:
# 0.45

# %%
n[0:6]
# Out:
# [0.45, 45, 33, 4, 6, 7]

# %%
n[0:68:3]
# Out:
# [0.45, 4, 89, 4, 'kjernoj']

# %%
n[::-1]
# Out:
# ['kjernoj', 'abhinav', 55, 4, 2235, 9, 89, 7, 6, 4, 33, 45, 0.45]

# %%
n
# Out:
# [0.45, 45, 33, 4, 6, 7, 89, 9, 2235, 4, 55, 'abhinav', 'kjernoj']

# %%
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
df.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
df.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
df["city"]
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
type(df["city"])
# Out:
# pandas.core.series.Series

# %%
df[["city"]]
# Out:
#                    city
# 0          Redwood City
# 1             San Mateo
# 2             San Mateo
# 3             San Mateo
# 4             San Mateo
# 5            Menlo Park
# 6            Menlo Park
# 7            Menlo Park
# 8          Redwood City
# 9          Redwood City
# 10         Redwood City
# 11         Redwood City
# 12         Redwood City
# 13         Redwood City
# 14        San Francisco
# 15            Sunnyvale
# 16  South San Francisco
# 17         Redwood City
# 18            San Mateo
# 19              Belmont
# 20        San Francisco

# %%
df[["city"]][4:100:2]
# Out:
#                    city
# 4             San Mateo
# 6            Menlo Park
# 8          Redwood City
# 10         Redwood City
# 12         Redwood City
# 14        San Francisco
# 16  South San Francisco
# 18            San Mateo
# 20        San Francisco

# %%
df[["city"]][-1:0:-2]
# Out:
#                    city
# 20        San Francisco
# 18            San Mateo
# 16  South San Francisco
# 14        San Francisco
# 12         Redwood City
# 10         Redwood City
# 8          Redwood City
# 6            Menlo Park
# 4             San Mateo
# 2             San Mateo

# %%
# We can use list of list to avoid these situations
df[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-06c8fe62852e> in <cell line: 0>()
# ----> 1 df[-1]
#
# ...

# %%
list(df["address_1"][::2])
# Out:
# ['2600 Middlefield Road',
#  '24 Second Avenue',
#  '24 Second Avenue',
#  '500 Arbor Road',
#  '2510 Middlefield Road',
#  '2140 Euclid Avenue.',
#  '399 Marine Parkway.',
#  '1500 Valencia Street',
#  '409 South Spruce Avenue',
#  '19 West 39th Avenue',
#  '2013 Avenue of the fellows']

# %%
df.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# id                False
# location_id       False
# address_1          True
# address_2          True
# city               True
# state_province     True
# postal_code        True
# country            True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df9 = df.dtypes[df.dtypes == 'object']

# %%
df9.index
# Out:
# Index(['address_1', 'address_2', 'city', 'state_province', 'postal_code',
#        'country'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                      address_1  address_2                 city state_province  \
# 0        2600 Middlefield Road        NaN         Redwood City             CA
# 1             24 Second Avenue        NaN            San Mateo             CA
# 2             24 Second Avenue        NaN            San Mateo             CA
# 3             24 Second Avenue        NaN            San Mateo             CA
# 4             24 Second Avenue        NaN            San Mateo             CA
# 5            800 Middle Avenue        NaN           Menlo Park             CA
# 6               500 Arbor Road        NaN           Menlo Park             CA
# 7            800 Middle Avenue        NaN           Menlo Park             CA
# 8        2510 Middlefield Road        NaN         Redwood City             CA
# 9        1044 Middlefield Road        NaN         Redwood City             CA
# 10         2140 Euclid Avenue.        NaN         Redwood City             CA
# ...

# %%
df10 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df10.describe
# Out:
# <bound method NDFrame.describe of                      address_1  address_2                 city state_province  \
# 0        2600 Middlefield Road        NaN         Redwood City             CA
# 1             24 Second Avenue        NaN            San Mateo             CA
# 2             24 Second Avenue        NaN            San Mateo             CA
# 3             24 Second Avenue        NaN            San Mateo             CA
# 4             24 Second Avenue        NaN            San Mateo             CA
# 5            800 Middle Avenue        NaN           Menlo Park             CA
# 6               500 Arbor Road        NaN           Menlo Park             CA
# 7            800 Middle Avenue        NaN           Menlo Park             CA
# 8        2510 Middlefield Road        NaN         Redwood City             CA
# 9        1044 Middlefield Road        NaN         Redwood City             CA
# 10         2140 Euclid Avenue.        NaN         Redwood City             CA
# ...

# %%
df10.columns
# Out:
# Index(['address_1', 'address_2', 'city', 'state_province', 'postal_code',
#        'country'],
#       dtype='object')

# %%
df10["city"]
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
df10[["city","address_1"]]
# Out:
#                    city                   address_1
# 0          Redwood City       2600 Middlefield Road
# 1             San Mateo            24 Second Avenue
# 2             San Mateo            24 Second Avenue
# 3             San Mateo            24 Second Avenue
# 4             San Mateo            24 Second Avenue
# 5            Menlo Park           800 Middle Avenue
# 6            Menlo Park              500 Arbor Road
# 7            Menlo Park           800 Middle Avenue
# 8          Redwood City       2510 Middlefield Road
# 9          Redwood City       1044 Middlefield Road
# 10         Redwood City         2140 Euclid Avenue.
# 11         Redwood City       1044 Middlefield Road
# 12         Redwood City         399 Marine Parkway.
# 13         Redwood City          660 Veterans Blvd.
# 14        San Francisco        1500 Valencia Street
# 15            Sunnyvale         1161 South Bernardo
# 16  South San Francisco     409 South Spruce Avenue
# ...

# %%
df10["city"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: city, dtype: bool
